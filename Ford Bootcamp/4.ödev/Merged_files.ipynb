# %%
import pandas as pd
import time

# %%
df = pd.read_excel("attendee2.xlsx")
df1 = pd.read_csv("df1_dosyasi.csv")
df2 = pd.read_excel("demografik_bilgi.xlsx")

# %%
df2.shape
# Out:
# (3643, 4)

# %%
df_combine = df.merge(df2, left_on = "Email", right_on = "mail", how = "left")

# %%
df_combine = df_combine.drop([0], axis = 0)
df_combine
# Out:
#     Attended User Name (Original Name)                 Email  \
# 1        Yes                Murat Erem     merem@ford.com.tr
# 2        Yes           Yağmur Emiroğlu   yagmure@unitebt.com
# 3        Yes           Yağmur Emiroğlu   yagmure@unitebt.com
# 4        Yes           Yağmur Emiroğlu   yagmure@unitebt.com
# 5        Yes               Nejat Tanca    ntanca@ford.com.tr
# ..       ...                       ...                   ...
# 934      Yes             Görkem Çağlar   gcaglar@ford.com.tr
# 935      Yes              Aslı Buğdacı  abugdaci@ford.com.tr
# 936      Yes                 Emre Önel     eonel@ford.com.tr
# 937      Yes               Ferdi Bozan    fbozan@ford.com.tr
# 938      Yes               Ferdi Bozan    fbozan@ford.com.tr
#
#                  Join Time             Leave Time  Time in Session (minutes)  \
# 1    May 26, 2022 13:00:24  May 26, 2022 16:30:31                      211.0
# 2    May 26, 2022 13:56:43  May 26, 2022 15:42:24                      106.0
# 3    May 26, 2022 13:48:27  May 26, 2022 13:56:35                        9.0
# 4    May 26, 2022 13:03:47  May 26, 2022 13:48:17                       45.0
# 5    May 26, 2022 13:00:48  May 26, 2022 14:26:32                       86.0
# ..                     ...                    ...                        ...
# 934  May 26, 2022 13:34:34  May 26, 2022 15:28:41                      115.0
# 935  May 26, 2022 14:07:31  May 26, 2022 14:08:41                        2.0
# 936  May 26, 2022 13:28:02  May 26, 2022 13:43:16                       16.0
# 937  May 26, 2022 13:26:23  May 26, 2022 14:03:21                       37.0
# 938  May 26, 2022 14:06:39  May 26, 2022 16:45:39                      159.0
#
#     Is Guest Country/Region Name                  mail  \
# 1         No              Turkey     merem@ford.com.tr
# 2        Yes              Turkey                   NaN
# 3        Yes              Turkey                   NaN
# 4        Yes              Turkey                   NaN
# 5         No              Turkey    ntanca@ford.com.tr
# ..       ...                 ...                   ...
# 934       No              Turkey   gcaglar@ford.com.tr
# 935       No              Turkey  abugdaci@ford.com.tr
# 936       No              Turkey     eonel@ford.com.tr
# 937       No              Turkey    fbozan@ford.com.tr
# 938       No              Turkey    fbozan@ford.com.tr
#
#                                     dept cinsiyet        yas
# 1                            FORD TRUCKS    Erkek  56 & Üstü
# 2                                    NaN      NaN        NaN
# 3                                    NaN      NaN        NaN
# 4                                    NaN      NaN        NaN
# 5                           OPERASYONLAR    Erkek      51-55
# ..                                   ...      ...        ...
# 934  MÜHENDİSLİK VE TEKNOLOJİ GELİŞTİRME    Erkek      31-35
# 935                        TOPLAM KALİTE    Kadın      36-40
# 936  MÜHENDİSLİK VE TEKNOLOJİ GELİŞTİRME    Erkek      26-30
# 937                         OPERASYONLAR    Erkek      41-45
# 938                         OPERASYONLAR    Erkek      41-45
#
# [938 rows x 12 columns]

# %%
df_combine.to_excel("df_combined.xlsx")

# %%
print(df_combine.yas.unique().tolist())
# Out:
# ['56 & Üstü', nan, '51-55', '31-35', '26-30', '41-45', '46-50', '21-25', '36-40']

# %%
print(df_combine["User Name (Original Name)"].nunique())
# Out:
# 683
